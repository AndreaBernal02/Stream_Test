# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaBernal02/Stream_Test/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_raw= cv2.imread("mandrill_colour.png")

# %%
type(img_raw)
# Out:
# numpy.ndarray

# %%
img_raw.shape
# Out:
# (288, 288, 3)

# %%
plt.imshow(img_raw)

# %%
img_rgb=cv2.cvtColor(img_raw, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(img_rgb)

# %%
image_blank=np.zeros(shape=(512,512,3), dtype=np.int16)

# %%
plt.imshow(image_blank)

# %%
line_red=cv2.line(image_blank,(0,0),(511,511),(255,0,0),5)

# %%
plt.imshow(line_red)

# %%
line_red=cv2.line(image_blank,(0,0),(511,511),(0,255,0),5)

# %%
plt.imshow(line_red)

# %%
rectangle = cv2.rectangle(line_red,(364,0),(510,128),(0,0,255),5)

# %%
plt.imshow(rectangle)

# %%
test_image_gray = cv2.imread("baby1.png")

# %%
plt.imshow(test_image_gray, cmap="gray")

# %%
def covertToRGB(image):
  return cv2.cvtColor(image, cv2=COLOR_BGR2BG)

  test_image_color = convertToRGB(test_image)

# %%
plt.imshow(test_image_gray, cmap="")

# %%
hear_cascade_face = cv2.CascadeClassifier(hearcascade_frontalface_default.xml)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-651144207.py in <cell line: 0>()
# ----> 1 hear_cascade_face = cv2.CascadeClassifier(hearcascade_frontalface_default.xml)
#
# NameError: name 'hearcascade_frontalface_default' is not defined
